# %% [markdown]
# <a href="https://colab.research.google.com/github/Shimaliza/Coursera--Python-Tasks/blob/main/PY0101EN_5_2_API_2_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Simple APIs
# Random User and Fruitvice API Examples
#
# To start using the API you can install the randomuser library running the pip install command.

# %%
# !pip install randomuser
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting randomuser
#   Downloading randomuser-1.6.tar.gz (5.0 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: randomuser
#   Building wheel for randomuser (setup.py) ... done
#   Created wheel for randomuser: filename=randomuser-1.6-py3-none-any.whl size=5080 sha256=ecff8c84bccdc9ddb72ab2763ecad7b045a821fa0eb8911bfa3b281844734af9
#   Stored in directory: /root/.cache/pip/wheels/41/6f/23/878c103a235dc2d4e85a3965c124aae8a28470c541b81aa2ba
# Successfully built randomuser
# Installing collected packages: randomuser
# Successfully installed randomuser-1.6

# %%
from randomuser import RandomUser
import pandas as pd

# %% [markdown]
# First, we will create a random user object, r.

# %%
r = RandomUser()

# %%
some_list = r.generate_users(10)

# %%
some_list
# Out:
# [<randomuser.RandomUser at 0x7f9727536040>,
#  <randomuser.RandomUser at 0x7f9727536520>,
#  <randomuser.RandomUser at 0x7f9727536100>,
#  <randomuser.RandomUser at 0x7f9727536730>,
#  <randomuser.RandomUser at 0x7f9727536700>,
#  <randomuser.RandomUser at 0x7f9727536880>,
#  <randomuser.RandomUser at 0x7f97281bf970>,
#  <randomuser.RandomUser at 0x7f9704264d00>,
#  <randomuser.RandomUser at 0x7f9704264dc0>,
#  <randomuser.RandomUser at 0x7f9704264ac0>]

# %%
name = r.get_full_name()

# %%
for user in some_list:
    print (user.get_full_name()," ",user.get_email())
# Out:
# Ryan Abraham   ryan.abraham@example.com
# Daniel Johansen   daniel.johansen@example.com
# Bernard Sullivan   bernard.sullivan@example.com
# Lola Kennedy   lola.kennedy@example.com
# پریا یاسمی   pry.ysmy@example.com
# Lesa Garrett   lesa.garrett@example.com
# Damaris Van Bree   damaris.vanbree@example.com
# Amna Rahman   amna.rahman@example.com
# Brian Clark   brian.clark@example.com
# Gaëtan Vincent   gaetan.vincent@example.com

# %% [markdown]
# Exercise 1
# In this Exercise, generate photos of the random 5 users.

# %%
for user in some_list:
    print(user.get_picture())
# Out:
# https://randomuser.me/api/portraits/men/39.jpg
# https://randomuser.me/api/portraits/men/72.jpg
# https://randomuser.me/api/portraits/men/49.jpg
# https://randomuser.me/api/portraits/women/71.jpg
# https://randomuser.me/api/portraits/women/92.jpg
# https://randomuser.me/api/portraits/women/83.jpg
# https://randomuser.me/api/portraits/women/70.jpg
# https://randomuser.me/api/portraits/women/58.jpg
# https://randomuser.me/api/portraits/men/51.jpg
# https://randomuser.me/api/portraits/men/3.jpg

# %% [markdown]
# To generate a table with information about the users, we can write a function containing all desirable parameters. For example, name, gender, city, etc. The parameters will depend on the requirements of the test to be performed. We call the Get Methods, listed at the beginning of this notebook. Then, we return pandas dataframe with the users.
#
# def get_users():
#     users =[]
#
#     for user in RandomUser.generate_users(10):
#         users.append({"Name":user.get_full_name(),"Gender":user.get_gender(),"City":user.get_city(),"State":user.get_state(),"Email":user.get_email(), "DOB":user.get_dob(),"Picture":user.get_picture()})
#
#     return pd.DataFrame(users)
# def get_users():

# %%
def get_users():
    users =[]
     
    for user in RandomUser.generate_users(10):
        users.append({"Name":user.get_full_name(),"Gender":user.get_gender(),"City":user.get_city(),"State":user.get_state(),"Email":user.get_email(), "DOB":user.get_dob(),"Picture":user.get_picture()})
      
    return pd.DataFrame(users)

# %%
get_users()
# Out:
#             Name  Gender               City                  State  \
# 0  Iwan Fournier    male             Eisten  Appenzell Innerrhoden
# 1    Jordi Muñoz    male  Palma de Mallorca             País Vasco
# 2  Eevi Waisanen  female          Outokumpu       Northern Savonia
# 3    Romeo David    male             Ursins                 Luzern
# 4   Emil Tuomala    male          Oulunsalo                Lapland
# 5    Wolf Hilmer    male          Schlettau     Schleswig-Holstein
# 6     Deniz Kunt  female           Osmaniye                    Muş
# 7   Aysel Geelen  female        Zandberg Dr                Drenthe
# 8  Liliana Glatz  female              Geisa      Baden-Württemberg
# 9   Debra Parker  female               Cobh                Kildare
#
#                        Email                       DOB  \
# 0  iwan.fournier@example.com  1982-07-09T22:00:51.466Z
# 1    jordi.munoz@example.com  1956-03-10T21:05:56.377Z
# 2  eevi.waisanen@example.com  1978-10-17T09:39:17.616Z
# 3    romeo.david@example.com  1988-05-09T06:55:05.950Z
# 4   emil.tuomala@example.com  1982-06-20T23:32:02.838Z
# 5    wolf.hilmer@example.com  1951-01-27T21:58:00.044Z
# 6     deniz.kunt@example.com  1947-02-01T18:45:34.503Z
# 7   aysel.geelen@example.com  1955-04-13T07:35:39.393Z
# 8  liliana.glatz@example.com  1980-02-12T19:23:26.919Z
# 9   debra.parker@example.com  1973-08-06T10:28:04.598Z
#
#                                             Picture
# 0     https://randomuser.me/api/portraits/men/7.jpg
# 1     https://randomuser.me/api/portraits/men/6.jpg
# 2   https://randomuser.me/api/portraits/women/6.jpg
# 3    https://randomuser.me/api/portraits/men/43.jpg
# 4    https://randomuser.me/api/portraits/men/82.jpg
# 5    https://randomuser.me/api/portraits/men/25.jpg
# 6  https://randomuser.me/api/portraits/women/40.jpg
# 7  https://randomuser.me/api/portraits/women/58.jpg
# 8  https://randomuser.me/api/portraits/women/41.jpg
# 9   https://randomuser.me/api/portraits/women/4.jpg

# %% [markdown]
# Example 2: Fruitvice API

# %%
import requests
import json

# %% [markdown]
# We will obtain the fruitvice API data using requests.get("url") function. The data is in a json format.

# %%
data = requests.get("https://fruityvice.com/api/fruit/all")

# %% [markdown]
# We will retrieve results using json.loads() function.

# %%
results = json.loads(data.text)

# %% [markdown]
# We will convert our json data into pandas data frame.

# %%
pd.DataFrame(results)
# Out:
#            genus          name  id           family             order  \
# 0          Malus         Apple   6         Rosaceae           Rosales
# 1         Prunus       Apricot  35         Rosaceae           Rosales
# 2         Persea       Avocado  84        Lauraceae          Laurales
# 3           Musa        Banana   1         Musaceae      Zingiberales
# 4          Rubus    Blackberry  64         Rosaceae           Rosales
# 5       Fragaria     Blueberry  33         Rosaceae           Rosales
# 6         Prunus        Cherry   9         Rosaceae           Rosales
# 7      Vaccinium     Cranberry  87        Ericaceae          Ericales
# 8   Selenicereus   Dragonfruit  80        Cactaceae    Caryophyllales
# 9          Durio        Durian  60        Malvaceae          Malvales
# 10    Sellowiana        Feijoa  76        Myrtaceae        Myrtoideae
# 11         Ficus           Fig  68         Moraceae           Rosales
# 12         Ribes    Gooseberry  69  Grossulariaceae      Saxifragales
# 13         Vitis         Grape  81         Vitaceae           Vitales
# 14         Malus    GreenApple  72         Rosaceae           Rosales
# 15       Psidium         Guava  37        Myrtaceae          Myrtales
# 16       Apteryx          Kiwi  66    Actinidiaceae  Struthioniformes
# 17     Actinidia     Kiwifruit  85    Actinidiaceae          Ericales
# 18        Citrus         Lemon  26         Rutaceae        Sapindales
# 19        Citrus          Lime  44         Rutaceae        Sapindales
# 20     Vaccinium   Lingonberry  65        Ericaceae          Ericales
# 21        Litchi        Lychee  67      Sapindaceae        Sapindales
# 22     Mangifera         Mango  27    Anacardiaceae        Sapindales
# 23       Cucumis         Melon  41    Cucurbitaceae     Cucurbitaceae
# 24         Morus         Morus  82         Moraceae           Rosales
# 25        Citrus        Orange   2         Rutaceae        Sapindales
# 26        Carica        Papaya  42       Caricaceae         Caricacea
# 27    Passiflora  Passionfruit  70   Passifloraceae      Malpighiales
# 28        Prunus         Peach  86         Rosaceae           Rosales
# 29         Pyrus          Pear   4         Rosaceae           Rosales
# 30     Diospyros     Persimmon  52        Ebenaceae           Rosales
# 31        Ananas     Pineapple  10     Bromeliaceae            Poales
# 32     Cactaceae      Pitahaya  78        Cactaceae    Caryophyllales
# 33        Prunus          Plum  71         Rosaceae           Rosales
# 34        Punica   Pomegranate  79       Lythraceae          Myrtales
# 35         Rubus     Raspberry  23         Rosaceae           Rosales
# 36      Fragaria    Strawberry   3         Rosaceae           Rosales
# 37        Citrus     Tangerine  77         Rutaceae        Sapindales
# 38       Solanum        Tomato   5       Solanaceae         Solanales
# 39     Citrullus    Watermelon  25    Cucurbitaceae      Cucurbitales
#
#                                            nutritions
# 0   {'carbohydrates': 11.4, 'protein': 0.3, 'fat':...
# 1   {'carbohydrates': 3.9, 'protein': 0.5, 'fat': ...
# 2   {'carbohydrates': 8.53, 'protein': 2, 'fat': 1...
# 3   {'carbohydrates': 22, 'protein': 1, 'fat': 0.2...
# 4   {'carbohydrates': 9, 'protein': 1.3, 'fat': 0....
# 5   {'carbohydrates': 5.5, 'protein': 0, 'fat': 0....
# 6   {'carbohydrates': 12, 'protein': 1, 'fat': 0.3...
# 7   {'carbohydrates': 12.2, 'protein': 0.4, 'fat':...
# 8   {'carbohydrates': 9, 'protein': 9, 'fat': 1.5,...
# 9   {'carbohydrates': 27.1, 'protein': 1.5, 'fat':...
# 10  {'carbohydrates': 8, 'protein': 0.6, 'fat': 0....
# 11  {'carbohydrates': 19, 'protein': 0.8, 'fat': 0...
# 12  {'carbohydrates': 10, 'protein': 0.9, 'fat': 0...
# 13  {'carbohydrates': 18.1, 'protein': 0.72, 'fat'...
# 14  {'carbohydrates': 3.1, 'protein': 0.4, 'fat': ...
# 15  {'carbohydrates': 14, 'protein': 2.6, 'fat': 1...
# 16  {'carbohydrates': 15, 'protein': 1.1, 'fat': 0...
# 17  {'carbohydrates': 14.6, 'protein': 1.14, 'fat'...
# 18  {'carbohydrates': 9, 'protein': 1.1, 'fat': 0....
# 19  {'carbohydrates': 8.4, 'protein': 0.3, 'fat': ...
# 20  {'carbohydrates': 11.3, 'protein': 0.75, 'fat'...
# 21  {'carbohydrates': 17, 'protein': 0.8, 'fat': 0...
# 22  {'carbohydrates': 15, 'protein': 0.82, 'fat': ...
# 23  {'carbohydrates': 8, 'protein': 0, 'fat': 0, '...
# 24  {'carbohydrates': 9.8, 'protein': 1.44, 'fat':...
# 25  {'carbohydrates': 8.3, 'protein': 1, 'fat': 0....
# 26  {'carbohydrates': 11, 'protein': 0, 'fat': 0.4...
# 27  {'carbohydrates': 22.4, 'protein': 2.2, 'fat':...
# 28  {'carbohydrates': 9.5, 'protein': 0.9, 'fat': ...
# 29  {'carbohydrates': 15, 'protein': 0.4, 'fat': 0...
# 30  {'carbohydrates': 18, 'protein': 0, 'fat': 0, ...
# 31  {'carbohydrates': 13.12, 'protein': 0.54, 'fat...
# 32  {'carbohydrates': 7, 'protein': 1, 'fat': 0.4,...
# 33  {'carbohydrates': 11.4, 'protein': 0.7, 'fat':...
# 34  {'carbohydrates': 18.7, 'protein': 1.7, 'fat':...
# 35  {'carbohydrates': 12, 'protein': 1.2, 'fat': 0...
# 36  {'carbohydrates': 5.5, 'protein': 0.8, 'fat': ...
# 37  {'carbohydrates': 8.3, 'protein': 0, 'fat': 0....
# 38  {'carbohydrates': 3.9, 'protein': 0.9, 'fat': ...
# 39  {'carbohydrates': 8, 'protein': 0.6, 'fat': 0....

# %% [markdown]
# The result is in a nested json format. The 'nutrition' column contains multiple subcolumns, so the data needs to be 'flattened' or normalized.

# %%
df2 = pd.json_normalize(results)

# %%
df2
# Out:
#            genus          name  id           family             order  \
# 0          Malus         Apple   6         Rosaceae           Rosales
# 1         Prunus       Apricot  35         Rosaceae           Rosales
# 2         Persea       Avocado  84        Lauraceae          Laurales
# 3           Musa        Banana   1         Musaceae      Zingiberales
# 4          Rubus    Blackberry  64         Rosaceae           Rosales
# 5       Fragaria     Blueberry  33         Rosaceae           Rosales
# 6         Prunus        Cherry   9         Rosaceae           Rosales
# 7      Vaccinium     Cranberry  87        Ericaceae          Ericales
# 8   Selenicereus   Dragonfruit  80        Cactaceae    Caryophyllales
# 9          Durio        Durian  60        Malvaceae          Malvales
# 10    Sellowiana        Feijoa  76        Myrtaceae        Myrtoideae
# 11         Ficus           Fig  68         Moraceae           Rosales
# 12         Ribes    Gooseberry  69  Grossulariaceae      Saxifragales
# 13         Vitis         Grape  81         Vitaceae           Vitales
# 14         Malus    GreenApple  72         Rosaceae           Rosales
# 15       Psidium         Guava  37        Myrtaceae          Myrtales
# 16       Apteryx          Kiwi  66    Actinidiaceae  Struthioniformes
# 17     Actinidia     Kiwifruit  85    Actinidiaceae          Ericales
# 18        Citrus         Lemon  26         Rutaceae        Sapindales
# 19        Citrus          Lime  44         Rutaceae        Sapindales
# 20     Vaccinium   Lingonberry  65        Ericaceae          Ericales
# 21        Litchi        Lychee  67      Sapindaceae        Sapindales
# 22     Mangifera         Mango  27    Anacardiaceae        Sapindales
# 23       Cucumis         Melon  41    Cucurbitaceae     Cucurbitaceae
# 24         Morus         Morus  82         Moraceae           Rosales
# 25        Citrus        Orange   2         Rutaceae        Sapindales
# 26        Carica        Papaya  42       Caricaceae         Caricacea
# 27    Passiflora  Passionfruit  70   Passifloraceae      Malpighiales
# 28        Prunus         Peach  86         Rosaceae           Rosales
# 29         Pyrus          Pear   4         Rosaceae           Rosales
# 30     Diospyros     Persimmon  52        Ebenaceae           Rosales
# 31        Ananas     Pineapple  10     Bromeliaceae            Poales
# 32     Cactaceae      Pitahaya  78        Cactaceae    Caryophyllales
# 33        Prunus          Plum  71         Rosaceae           Rosales
# 34        Punica   Pomegranate  79       Lythraceae          Myrtales
# 35         Rubus     Raspberry  23         Rosaceae           Rosales
# 36      Fragaria    Strawberry   3         Rosaceae           Rosales
# 37        Citrus     Tangerine  77         Rutaceae        Sapindales
# 38       Solanum        Tomato   5       Solanaceae         Solanales
# 39     Citrullus    Watermelon  25    Cucurbitaceae      Cucurbitales
#
#     nutritions.carbohydrates  nutritions.protein  nutritions.fat  \
# 0                      11.40                0.30            0.40
# 1                       3.90                0.50            0.10
# 2                       8.53                2.00           14.66
# 3                      22.00                1.00            0.20
# 4                       9.00                1.30            0.40
# 5                       5.50                0.00            0.40
# 6                      12.00                1.00            0.30
# 7                      12.20                0.40            0.10
# 8                       9.00                9.00            1.50
# 9                      27.10                1.50            5.30
# 10                      8.00                0.60            0.40
# 11                     19.00                0.80            0.30
# 12                     10.00                0.90            0.60
# 13                     18.10                0.72            0.16
# 14                      3.10                0.40            0.10
# 15                     14.00                2.60            1.00
# 16                     15.00                1.10            0.50
# 17                     14.60                1.14            0.50
# 18                      9.00                1.10            0.30
# 19                      8.40                0.30            0.10
# 20                     11.30                0.75            0.34
# 21                     17.00                0.80            0.44
# 22                     15.00                0.82            0.38
# 23                      8.00                0.00            0.00
# 24                      9.80                1.44            0.39
# 25                      8.30                1.00            0.20
# 26                     11.00                0.00            0.40
# 27                     22.40                2.20            0.70
# 28                      9.50                0.90            0.25
# 29                     15.00                0.40            0.10
# 30                     18.00                0.00            0.00
# 31                     13.12                0.54            0.12
# 32                      7.00                1.00            0.40
# 33                     11.40                0.70            0.28
# 34                     18.70                1.70            1.20
# 35                     12.00                1.20            0.70
# 36                      5.50                0.80            0.40
# 37                      8.30                0.00            0.40
# 38                      3.90                0.90            0.20
# 39                      8.00                0.60            0.20
#
#     nutritions.calories  nutritions.sugar
# 0                    52             10.30
# 1                    15              3.20
# 2                   160              0.66
# 3                    96             17.20
# 4                    40              4.50
# 5                    29              5.40
# 6                    50              8.00
# 7                    46              4.00
# 8                    60              8.00
# 9                   147              6.75
# 10                   44              3.00
# 11                   74             16.00
# 12                   44              0.00
# 13                   69             16.00
# 14                   21              6.40
# 15                   68              9.00
# 16                   61              9.00
# 17                   61              8.90
# 18                   29              2.50
# 19                   25              1.70
# 20                   50              5.74
# 21                   66             15.00
# 22                   60             13.70
# 23                   34              8.00
# 24                   43              8.10
# 25                   43              8.20
# 26                   43              1.00
# 27                   97             11.20
# 28                   39              8.40
# 29                   57             10.00
# 30                   81             18.00
# 31                   50              9.85
# 32                   36              3.00
# 33                   46              9.92
# 34                   83             13.70
# 35                   53              4.40
# 36                   29              5.40
# 37                   45              9.10
# 38                   74              2.60
# 39                   30              6.00

# %% [markdown]
# Let's see if we can extract some information from this dataframe. Perhaps, we need to know the family and genus of a cherry.

# %%
cherry = df2.loc[df2["name"] == 'Cherry']
(cherry.iloc[0]['family']) , (cherry.iloc[0]['genus'])
# Out:
# ('Rosaceae', 'Prunus')

# %% [markdown]
# Exercise 2
# In this Exercise, find out how many calories are contained in a banana.

# %%
cal_banana = df2.loc[df2["name"] == 'Banana']
cal_banana.iloc[0]['nutritions.calories']
# Out:
# 96

# %% [markdown]
# Exercise 3
#
# This page contains a list of free public APIs. Choose any API of your interest and use it to load/extract some information, as shown in the example above.
#
# Using requests.get("url") function, load your data

# %%
data2 = requests.get("https://www.fishwatch.gov/api/species")

# %%
results2 = json.loads(data2.text)

# %%
df3 = pd.DataFrame(results2)
df3
# Out:
#                                     Fishery Management  \
# 0    <ul>\n<li><a href="https://www.fisheries.noaa....
# 1    <ul>\n<li><a href="https://www.fisheries.noaa....
# 2    <ul>\n<li>\n<p><a href="https://archive.fisher...
# 3    <ul>\n<li><a href="https://www.fisheries.noaa....
# 4    <ul>\n<li>The states and <a href="https://www....
# ..                                                 ...
# 111  <ul>\n<li><a href="https://www.fisheries.noaa....
# 112  <ul>\n<li><a href="https://www.greateratlantic...
# 113  <ul>\n<li><a href="http://sero.nmfs.noaa.gov/"...
# 114  <ul>\n<li><a href="https://sero.nmfs.noaa.gov/...
# 115  <ul>\n<li>There are two stocks of Atlantic cod...
#
#                                                Habitat  \
# 0                                                 None
# 1    <ul>\n<li>White hake are groundfish, meaning t...
# 2    <ul>\n<li>Atlantic chub mackerel are a schooli...
# 3    <ul>\n<li>Shortfin squid live in deep and shal...
# 4    <ul>\n<li>American lobsters live on the ocean ...
# ..                                                 ...
# 111  <ul>\n<li>Younger pollock live in the mid-wate...
# 112  <ul>\n<li>Monkfish live on the ocean floor, ty...
# 113  <ul>\n<li>Mahi mahi live near the surface in t...
# 114  <ul>\n<li>Cobia are found near structures in t...
# 115  <ul>\n<li>Atlantic cod live near the ocean flo...
#
#                                        Habitat Impacts  \
# 0    Bottomfish fishing operations, typically using...
# 1    Area closures and gear restrictions protect ha...
# 2    Area closures and gear restrictions protect ha...
# 3    Fishing gears used to harvest shortfin squid h...
# 4    Fishing gears used to harvest American lobster...
# ..                                                 ...
# 111  The Alaska pollock fishery uses midwater trawl...
# 112  Area closures and gear restrictions protect ha...
# 113  Fishing gear used to catch mahi mahi rarely co...
# 114  Fishing gear used to catch cobia rarely contac...
# 115  Area closures and gear restrictions protect ha...
#
#                                          Image Gallery  \
# 0    [{'src': 'https://origin-east-01-drupal-fishwa...
# 1    [{'src': 'https://origin-east-01-drupal-fishwa...
# 2    [{'src': 'https://origin-east-01-drupal-fishwa...
# 3                                                 None
# 4    [{'src': 'https://origin-east-01-drupal-fishwa...
# ..                                                 ...
# 111  [{'src': 'https://origin-east-01-drupal-fishwa...
# 112  [{'src': 'https://origin-east-01-drupal-fishwa...
# 113  [{'src': 'https://origin-east-01-drupal-fishwa...
# 114  [{'src': 'https://origin-east-01-drupal-fishwa...
# 115  [{'src': 'https://origin-east-01-drupal-fishwa...
#
#                                               Location Management  \
# 0    <ul>\n<li>Crimson jobfish are distributed thro...       None
# 1    <ul>\n<li>White hake are found in the northwes...       None
# 2    <ul>\n<li>Atlantic chub mackerel in the wester...       None
# 3    <ul>\n<li>Shortfin squid inhabits the continen...       None
# 4    <ul>\n<li>American lobsters are found in the n...       None
# ..                                                 ...        ...
# 111  <ul>\n<li>Alaska pollock are found throughout ...       None
# 112  <ul>\n<li>Monkfish are found in the Northwest ...       None
# 113  <ul>\n<li>Mahi mahi are found in the Atlantic,...       None
# 114  <ul>\n<li>In U.S. waters, cobia are most abund...       None
# 115  <ul>\n<li>In the Northwest Atlantic, cod range...       None
#
#            NOAA Fisheries Region  \
# 0                Pacific Islands
# 1               Greater Atlantic
# 2               Greater Atlantic
# 3               Greater Atlantic
# 4               Greater Atlantic
# ..                           ...
# 111                       Alaska
# 112  Greater Atlantic, Southeast
# 113  Greater Atlantic, Southeast
# 114  Greater Atlantic, Southeast
# 115             Greater Atlantic
#
#                                             Population  \
# 0    The population level is unknown, but the stock...
# 1                         The stock is not overfished.
# 2     The population level is unknown, but manageme...
# 3    The population level is unknown, but managemen...
# 4    The Gulf of Maine/Georges Bank stock is not ov...
# ..                                                 ...
# 111  The Aleutian Islands, Eastern Bering Sea, and ...
# 112  The population level is unknown and management...
# 113        The South Atlantic stock is not overfished.
# 114                       The stock is not overfished.
# 115  The Gulf of Maine and Georges Bank stocks are ...
#
#                                      Population Status  \
# 0    <ul>\n<li>There are five stocks of crimson job...
# 1    <ul>\n<li>According to the 2022&nbsp;stock ass...
# 2    <p>Atlantic chub mackerel has never been asses...
# 3    <ul>\n<li>According to the latest assessment (...
# 4    <ul>\n<li>According to the 2020&nbsp;<a href="...
# ..                                                 ...
# 111  <ul>\n<li>There are five stocks of walleye pol...
# 112  <ul>\n<li>There are two stocks of monkfish: Gu...
# 113  <p>There are two stocks of dolphinfish: a Sout...
# 114  <ul>\n<li>\n<p>According to the 2020 stock ass...
# 115  <ul>\n<li>There are two stocks of Atlantic cod...
#
#                  Scientific Name  ...  Selenium Serving Weight Servings  \
# 0    Pristipomoides filamentosus  ...  38.2 mcg    100 g (raw)        1
# 1               Urophycis tenuis  ...  32.1 mcg    100 g (raw)        1
# 2                 Scomber colias  ...  44.1 mcg    100 g (raw)        1
# 3             Illex illecebrosus  ...  44.8 mcg          100 g        1
# 4             Homarus americanus  ...  41.4 mcg    100 g (raw)        1
# ..                           ...  ...       ...            ...      ...
# 111          Gadus chalcogrammus  ...  21.9 mcg    100 g (raw)        1
# 112           Lophius americanus  ...  36.5 mcg    100 g (raw)        1
# 113          Coryphaena hippurus  ...  36.5 mcg    100 g (raw)        1
# 114         Rachycentron canadum  ...  36.5 mcg    100 g (raw)        1
# 115                 Gadus morhua  ...  33.1 mcg          100 g        1
#
#      Sodium                                             Source Sugars, Total  \
# 0     64 mg  <p>U.S -wild caught around Hawaii and Pacific ...           0 g
# 1     72 mg  <p>White hake is wild-caught from Maine to sou...           0 g
# 2     90 mg  <p>U.S. wild caught from Southern New England ...           0 g
# 3     44 mg  <p>U.S. wild-caught from Maine to North Caroli...           0 g
# 4    296 mg  <p>U.S. wild-caught from Maine to North Caroli...           0 g
# ..      ...                                                ...           ...
# 111   99 mg  <p>U.S. wild-caught, mainly in the Bering Sea ...           0 g
# 112   18 mg  <p>U.S. wild-caught from Maine to North Caroli...           0 g
# 113   88 mg  <p>Wild-caught from Massachusetts to Texas.</p>\n           0 g
# 114  135 mg  <p>Wild-caught from Virginia to Texas. Cobia i...           0 g
# 115   54 mg       <p>Wild-caught from Maine to Virginia.</p>\n           0 g
#
#                                                  Taste  \
# 0      <p>Crimson jobfish has a delicate flavor.</p>\n
# 1    <p>White hake has a mild, almost sweet&nbsp;ta...
# 2                    <p>Rich, pronounced flavor.</p>\n
# 3      <p>Mild, and subtly sweet.</p>\n<p>&nbsp;</p>\n
# 4                             <p>Mild and sweet.</p>\n
# ..                                                 ...
# 111  <p>Pollock has mild-tasting flesh and is simil...
# 112                                     <p>Mild.</p>\n
# 113  <p>Mahi mahi has a sweet, mild flavor. For a m...
# 114           <p>Cobia has a sweet, rich flavor.</p>\n
# 115  <p>Atlantic cod has a mild clean flavor. It is...
#
#                                                Texture  \
# 0    <p>Crimson jobfish has&nbsp;a firm texture and...
# 1    <p>White hake has a soft, delicate texture tha...
# 2                     <p>Soft, flaky, and moist.</p>\n
# 3                             <p>Firm and meaty.</p>\n
# 4    <p>The meat is firm and somewhat fibrous. The ...
# ..                                                 ...
# 111  <p>Pollock has a relatively fine texture and i...
# 112  <p>The tail meat is firm, dense, and relativel...
# 113  <p>Mahi mahi is lean and fairly firm with larg...
# 114  <p>Cobia is lean, moist, and firm with a nice ...
# 115  <p>Cod has large flakes. It's less firm than h...
#
#                                  Path         last_update
# 0           /profiles/crimson-jobfish  06/21/2022 - 12:00
# 1                /profiles/white-hake  01/11/2023 - 17:11
# 2    /profiles/atlantic-chub-mackerel  01/25/2023 - 09:57
# 3            /profiles/shortfin-squid  01/24/2023 - 12:42
# 4          /profiles/american-lobster  01/26/2023 - 15:22
# ..                                ...                 ...
# 111          /profiles/alaska-pollock  01/20/2023 - 15:00
# 112                /profiles/monkfish  01/11/2023 - 15:47
# 113      /profiles/atlantic-mahi-mahi  01/26/2023 - 14:51
# 114                   /profiles/cobia  01/18/2023 - 12:23
# 115            /profiles/atlantic-cod  01/19/2023 - 17:28
#
# [116 rows x 56 columns]
